# %%
import pandas as pd
import joblib

# Descargar el modelo desde GitHub y guardarlo localmente
model_url = 'https://github.com/FabianaLuciano/TRABAJO-ROBLOX/raw/master/modelo_nlp.pkl'
model_filename = 'modelo_nlp.pkl'
# !wget {model_url} -O {model_filename}

# Cargar el modelo
model = joblib.load(model_filename)

# Verificar que el modelo se haya cargado correctamente
print("Modelo cargado correctamente.")
# Out:
# --2024-08-26 17:37:36--  https://github.com/FabianaLuciano/TRABAJO-ROBLOX/raw/master/modelo_nlp.pkl
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/FabianaLuciano/TRABAJO-ROBLOX/master/modelo_nlp.pkl [following]
# --2024-08-26 17:37:37--  https://raw.githubusercontent.com/FabianaLuciano/TRABAJO-ROBLOX/master/modelo_nlp.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1509310 (1.4M) [application/octet-stream]
# Saving to: ‘modelo_nlp.pkl’
#
# modelo_nlp.pkl      100%[===================>]   1.44M  --.-KB/s    in 0.01s
#
# 2024-08-26 17:37:37 (138 MB/s) - ‘modelo_nlp.pkl’ saved [1509310/1509310]
#
# Modelo cargado correctamente.

# %%
import pandas as pd

# Suponiendo que el archivo subido se llama 'simonazosimon - Roblox.csv'
csv_filename = 'simonazosimon - Roblox.csv'

# Cargar el archivo CSV con el historial de juegos
df = pd.read_csv(csv_filename)

# Mostrar las primeras filas del DataFrame para verificar la carga correcta
print(df.head())
# Out:
#                                               Título  \
# 0  \n                Ragdoll on Skates Obby!\n   ...
# 1  \n                Strongest Fart Simulator\n  ...
# 2  \n                Wheel Drawing Obby\n        ...
# 3  \n                Fire or Water Obby\n        ...
# 4  \n                [W43] Obby But You’re On a B...
#
#                                           Título_URL  \
# 0  https://www.roblox.com/es/games/refer?SortFilt...
# 1  https://www.roblox.com/es/games/refer?SortFilt...
# 2  https://www.roblox.com/es/games/refer?SortFilt...
# 3  https://www.roblox.com/es/games/refer?SortFilt...
# 4  https://www.roblox.com/es/games/refer?SortFilt...
#
#                                               Imagen  \
# 0  https://tr.rbxcdn.com/f4eb903d5b399aea7e7b87c1...
# 1  https://tr.rbxcdn.com/90315285f76ff8ba74a642f1...
# 2  https://tr.rbxcdn.com/a95b04339500c54fbc1c233e...
# 3  https://tr.rbxcdn.com/3dc9d3f47317a2b870f38577...
# 4  https://tr.rbxcdn.com/7517d827609988a732e28b49...
#
#                                       Palabras_clave
# 0  \n                    \n                    51...
# 1  \n                    \n                    91...
# 2  \n                    \n                    50...
# 3  \n                    \n                    50...
# 4  \n                    \n                    76...

# %%
# Preprocesamiento del texto (ajustar según sea necesario)
def preprocess_text(text):
    # Implementa el preprocesamiento necesario para tu modelo
    return text

# Agregar una columna para los resultados
df['es_violento'] = ''

# Procesar cada juego
for index, row in df.iterrows():
    game_name = row['Título']  # Reemplaza con el nombre de la columna correspondiente
    full_text = preprocess_text(game_name)  # Aplica el preprocesamiento necesario

    # Realizar la predicción
    try:
        prediction = model.predict([full_text])[0]
    except Exception as e:
        print(f"Error al predecir el juego '{game_name}': {e}")
        prediction = None  # O algún valor por defecto

    # Decidir el mensaje basado en la predicción
    if prediction == 1:
        result = "Este juego es violento"
    elif prediction == 0:
        result = "Este juego parece apropiado"
    else:
        result = "Predicción no válida"

    # Guardar el resultado en el DataFrame
    df.at[index, 'es_violento'] = result

# Guardar los resultados en un nuevo archivo CSV en el directorio actual
output_filename = '/content/historial_clasificado.csv'
df.to_csv(output_filename, index=False)

print(f"Archivo guardado en: {output_filename}")
# Out:
# Archivo guardado en: /content/historial_clasificado.csv

# %%
import pandas as pd

# Supongamos que df es el DataFrame con todas las columnas
# Filtrar las columnas necesarias
df_filtered = df[['Título', 'es_violento']]

# Guardar el DataFrame filtrado en un nuevo archivo CSV
output_filename = '/content/historial_clasificado.csv'  # Ruta para guardar el archivo
df_filtered.to_csv(output_filename, index=False)

print(f"Archivo CSV guardado en {output_filename}")
# Out:
# Archivo CSV guardado en /content/historial_clasificado.csv

# %%
import pandas as pd
from google.colab import files

# Leer el archivo CSV guardado
csv_path = '/content/historial_clasificado.csv'  # Asegúrate de que esta ruta sea correcta
df_classified = pd.read_csv(csv_path)

# Mostrar el DataFrame de manera interactiva
import IPython.display as display
display.display(df_classified)
# Out:
#                                               Título  \
# 0  \n                Ragdoll on Skates Obby!\n   ...
# 1  \n                Strongest Fart Simulator\n  ...
# 2  \n                Wheel Drawing Obby\n        ...
# 3  \n                Fire or Water Obby\n        ...
# 4  \n                [W43] Obby But You’re On a B...
# 5  \n                2 Player Evolution Tycoon\n ...
#
#                    es_violento
# 0       Este juego es violento
# 1  Este juego parece apropiado
# 2  Este juego parece apropiado
# 3  Este juego parece apropiado
# 4  Este juego parece apropiado
# 5       Este juego es violento
